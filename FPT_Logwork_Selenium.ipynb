# %% [markdown]
# <a href="https://colab.research.google.com/github/southnt/colab/blob/main/FPT_Logwork_Selenium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lương FPT
#
#
# ```
# 年収 = (basic_salary + housing + allowance)*12 + basic_salary*bonus_month + flight_ticket + other
#
# ```

# %%
basic_salary = 32 #@param {type:"integer"}
allowance =  5#@param {type:"integer"}
housing =  3#@param {type:"integer"}
bonus_month = 2 #@param {type:"integer"}
flight_ticket = 8 #@param {type:"integer"}
other = 0 #@param {type:"integer"}

nen_shu = (basic_salary + housing + allowance)*12 + basic_salary*bonus_month + flight_ticket + other
print("年収 ＝",nen_shu)
# Out:
# 年収 ＝ 552

# %% [markdown]
# # FJP - AutoLog -  Free version
# # @Copyright: Namnt54
#
# Save my time for my life
#
# ----
#
# ## [Format Googledoc](https://docs.google.com/spreadsheets/d/1whv1BHrPLmekpBQRn4bFbkGZZw-F6U6lirv_UQxNo6k/edit?usp=sharing) download in csv format
# ## Timesheet: https://employee.fjpservice.com/timesheet/my

# %%
# Install
# !apt-get update > /dev/null
# !apt install chromium-chromedriver > /dev/null
# !pip install selenium &> /dev/null

from google.colab import files, output
from selenium import webdriver
import time, os
import pandas as pd

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# Upload file
_ = files.upload()
# Clear screen
output.clear()

file_name = [csvFile for csvFile in os.listdir("./") if csvFile.endswith(".csv")]
file_name = file_name[0]

# Github credentials
username = "NamNT54" #@param {type: "string"}
password = "pass" #@param {type: "string"}
logwork_for = "Previous month" #@param ["Current month", "Previous month"]
# file_name = "xxx.csv" #@param {type: "string"}
working_place = "2" #@param ["2", "3", "4", "5"]
#@markdown working_place Values:
#@markdown * 2=Customer office
#@markdown * 3=FJP Office
#@markdown * 4=WFH
#@markdown * 5=WFH & FJP Office


# Read timesheet (csv format)
df = pd.read_csv(file_name)
In_time = [str(in_time) for in_time  in df.iloc[6:,3]]
Out_time = [str(out_time) for out_time in df.iloc[6:,4]]
Break_time = [str(break_time) for break_time in df.iloc[6:,5]]


# Setting Chrome webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=options)


# Login
driver.get("https://employee.fjpservice.com/login")
driver.find_element(By.ID, "userId").send_keys(username)
driver.find_element(By.ID, "password").send_keys(password)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
time.sleep(30)


# Click Timesheet
driver.find_element(By.XPATH, "//html/body/app/main/main/ba-sidebar/aside/ba-menu/aside/div[1]/ul/ba-menu-item[6]/li/a/b").click()
time.sleep(1)
# Click My Timesheet
driver.find_element(By.XPATH, "//html/body/app/main/main/ba-sidebar/aside/ba-menu/aside/div[1]/ul/ba-menu-item[6]/li/ul/ba-menu-item/li/a/span[1]").click()
time.sleep(1)


# Click New button
button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-approve-list/div/div/ba-card/div/div[2]/form/ul/li[1]/button")
driver.execute_script("arguments[0].click();", button)
time.sleep(10)


if(logwork_for == "Previous month"):
    # Click Plus button
    time.sleep(5)
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/p-fieldset/fieldset/legend/a/span[1]").click()
    time.sleep(1)

    # select month
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/p-fieldset/fieldset/div/div/div[1]/div[1]/div/div/p-dropdown/div/label").click()
    time.sleep(1)
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/p-fieldset/fieldset/div/div/div[1]/div[1]/div/div/p-dropdown/div/div[4]/div/ul/li[2]").click()
    # time.sleep(1)

    # Cleck Create/load
    button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/div/div/button")
    driver.execute_script("arguments[0].click();", button)

    # Click Confirmation: Yes
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/p-confirmdialog/div/div[3]/button[1]/span[1]").click()
    time.sleep(10)

# Close popup "Remind status of the Encouraging Annual Paid Leave"
# If not present, pass
try:
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/p-dialog[2]/div/div[3]/p-footer/button/span[2]").click()
except:
    pass

# Fill time to table
input_table = driver.find_elements(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr")
for i in range(len(input_table)):
    try:
        # Current working place, click dropdown -> select Customer office
        driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[17]/p-dropdown/div/div[3]/span").click()
        driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[17]/p-dropdown/div/div[4]/div/ul/li["+working_place+"]/span").click()
    except:
        # Pass if select is disabled 
        continue

    In = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[2]/p-inputmask/input")
    In.clear()
    In.send_keys("09:00")
    In.send_keys(Keys.RETURN)
    time.sleep(0.5)

    Out = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[3]/p-inputmask/input")
    Out.clear()
    Out.send_keys(Out_time[i])
    Out.send_keys(Keys.RETURN)
    time.sleep(0.5)

    Break = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[4]/p-inputmask/input")
    Break.clear()
    Break.send_keys("01:00")
    Break.send_keys(Keys.RETURN)
    time.sleep(0.5)


# Click Caculate
button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/ul/li[1]/button")
driver.execute_script("arguments[0].click();", button)
time.sleep(5)

Working_hour = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[3]/table/thead/tr/th[5]/span").text
if(df.iat[-1,6] == Working_hour):
    print("Working_hour is same with csv.")
    confirm = input('Do you want to submit the timesheet?: y/n ')
    if(confirm == "y"):
        # Click Submit
        button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/ul/li[3]/button")
        driver.execute_script("arguments[0].click();", button)
        time.sleep(1)
        # Click Yes
        driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/p-confirmdialog/div/div[3]/button[1]/span[2]").click()
        time.sleep(5)
        print("[+] Submit successful, check at: https://employee.fjpservice.com/timesheet/my")
        driver.quit()

# Click Save Draft
button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/ul/li[2]/button")
driver.execute_script("arguments[0].click();", button)
time.sleep(5)
print("[+] Save Draft successful, check at: https://employee.fjpservice.com/timesheet/my")
driver.quit()
# Out:
# Working_hour is same with csv.
# Do you want to submit the timesheet?: y/n n
# [+] Save Draft successful, check at: https://employee.fjpservice.com/timesheet/my

# %% [markdown]
# ## FPT fix OT

# %%
# Install
# !apt-get update > /dev/null
# !apt install chromium-chromedriver > /dev/null
# !pip install selenium &> /dev/null

from selenium import webdriver
import time, os
import pandas as pd

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC


# Github credentials
username = "NamNT54" #@param {type: "string"}
password = "pass" #@param {type: "string"}
logwork_for = "Previous month" #@param ["Current month", "Previous month"]
# file_name = "xxx.csv" #@param {type: "string"}
working_place = "4" #@param ["2", "3", "4", "5"]
#@markdown working_place Values:
#@markdown * 2=Customer office
#@markdown * 3=FJP Office
#@markdown * 4=WFH
#@markdown * 5=WFH & FJP Office


# Setting Chrome webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=options)


# Login
driver.get("https://employee.fjpservice.com/login")
driver.find_element(By.ID, "userId").send_keys(username)
driver.find_element(By.ID, "password").send_keys(password)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
time.sleep(30)


# Click Timesheet
driver.find_element(By.XPATH, "//html/body/app/main/main/ba-sidebar/aside/ba-menu/aside/div[1]/ul/ba-menu-item[6]/li/a/b").click()
time.sleep(1)
# Click My Timesheet
driver.find_element(By.XPATH, "//html/body/app/main/main/ba-sidebar/aside/ba-menu/aside/div[1]/ul/ba-menu-item[6]/li/ul/ba-menu-item/li/a/span[1]").click()
time.sleep(1)


# Click New button
button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-approve-list/div/div/ba-card/div/div[2]/form/ul/li[1]/button")
driver.execute_script("arguments[0].click();", button)
time.sleep(10)


if(logwork_for == "Previous month"):
    # Click Plus button
    time.sleep(5)
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/p-fieldset/fieldset/legend/a/span[1]").click()
    time.sleep(1)

    # select month
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/p-fieldset/fieldset/div/div/div[1]/div[1]/div/div/p-dropdown/div/label").click()
    time.sleep(1)
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/p-fieldset/fieldset/div/div/div[1]/div[1]/div/div/p-dropdown/div/div[4]/div/ul/li[2]").click()
    # time.sleep(1)

    # Cleck Create/load
    button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[1]/ba-card/div/div[2]/form/div/div/button")
    driver.execute_script("arguments[0].click();", button)

    # Click Confirmation: Yes
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/p-confirmdialog/div/div[3]/button[1]/span[1]").click()
    time.sleep(10)

# Close popup "Remind status of the Encouraging Annual Paid Leave"
# If not present, pass
try:
    driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/p-dialog[2]/div/div[3]/p-footer/button/span[2]").click()
except:
    pass

# Fill time to table
input_table = driver.find_elements(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr")
for i in range(len(input_table)):
    try:
        # Current working place, click dropdown -> select Customer office
        driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[17]/p-dropdown/div/div[3]/span").click()
        driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[17]/p-dropdown/div/div[4]/div/ul/li["+working_place+"]/span").click()
    except:
        # Pass if select is disabled 
        continue

    In = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[2]/p-inputmask/input")
    In.clear()
    In.send_keys("09:00")
    In.send_keys(Keys.RETURN)
    time.sleep(0.5)

    Out = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[3]/p-inputmask/input")
    Out.clear()
    Out.send_keys("18:00")
    Out.send_keys(Keys.RETURN)
    time.sleep(0.5)

    Break = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/div[2]/div[2]/table/tbody/tr["+str(i+1)+"]/td[4]/p-inputmask/input")
    Break.clear()
    Break.send_keys("01:00")
    Break.send_keys(Keys.RETURN)
    time.sleep(0.5)


# Click Caculate
button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/ul/li[1]/button")
driver.execute_script("arguments[0].click();", button)
time.sleep(5)

# Click Save Draft
button = driver.find_element(By.XPATH, "//html/body/app/main/main/div/div/timesheet-new/div/div[2]/ba-card/div/div[2]/ul/li[2]/button")
driver.execute_script("arguments[0].click();", button)
time.sleep(5)
print("[+] Save Draft successful, check at: https://employee.fjpservice.com/timesheet/my")
driver.quit()
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# [+] Save Draft successful, check at: https://employee.fjpservice.com/timesheet/my
